# %%
terrorism_search_queries = ["Al-Qaeda",
                          "terrorism",
                          "terror",
                          "attack",
                          "iraq",
                          "afghanistan",
                          "iran",
                          "Pakistan",
                          "Agro",
                          "Environmental Terrorism",
                          "Eco-Terrorism",
                          "Conventional Weapon",
                          "Weapons Grade",
                          "Dirty Bomb",
                          "Nuclear Enrichment",
                          "Nuclear",
                          "Chemical Weapon",
                          "Biological Weapon",
                          "Ammonium nitrate",
                          "Improvised Explosive Device",
                          "Abu Sayyaf",
                          "Hamas",
                          "FARC",
                          "Irish Republican Army",
                          "Euskadi ta Askatasuna ",
                          "Hezbollah",
                          "Tamil Tigers",
                          "PLO",
                          "Palestine Liberation Front",
                          "Car bomb",
                          "Jihad",
                          "Taliban",
                          "Suicide bomber",
                          "Suicide attack",
                          "AL Qaeda in the Arabian Peninsula",
                          "Al Qaeda in the Islamic Maghreb",
                          "Tehrik-i-Taliban Pakistan",
                          "Yemen",
                          "Pirates",
                          "Extremism",
                          "Somalia",
                          "Nigeria",
                          "Political radicalism",
                          "Al-Shabaab",
                          "Nationalism",
                          "Recruitment",
                          "Fundamentalism",
                          "Islamist"]

top_30_terrorism_search_queries = ["Al Qaeda",
                          "Terrorism",
                          "Terror",
                          "Environmental Terrorism",
                          "Eco-terrorism",
                          "Conventional Weapon",
                          "Weapons Grade",
                          "Dirty Bomb",
                          "Nuclear Enrichment",
                          "Nuclear",
                          "Chemical Weapon",
                          "Biological Weapon",
                          "Improvised Explosive Device",
                          "Abu Sayyaf",
                          "FARC",
                          "Euskadi ta Askatasuna ",
                          "Hezbollah",
                          "Palestine Liberation Front",
                          "Car bomb",
                          "Jihad",
                          "Taliban",
                          "Suicide bomber",
                          "Suicide attack",
                          "AL Qaeda in the Arabian Peninsula",
                          "Al Qaeda in the Islamic Maghreb",
                          "Tehrik-i-Taliban Pakistan",
                          "Political radicalism",
                          "Al-Shabaab",
                          "Recruitment",
                          "Islamist"]

domestic_search_queries = ["Department of Homeland Security",
                          "Federal Emergency Management Agency",
                          "Coast Guard",
                          "Customs and Border Protection ",
                          "Border patrol",
                          "Secret Service",
                          "Bureau of Land Management",
                          "Homeland defense",
                          "Espionage",
                          "Task Force 88",
                          "Central Intelligence Agency",
                          "Fusion center",
                          "DEA",
                          "Secure Border Initiative ",
                          "Federal Bureau of Investigation",
                          "Alcohol and Tobacco Tax and Trade Bureau",
                          "U.S. Citizenship and Immigration Services",
                          "Federal Air Marshal Service ",
                          "Transportation Security Administration",
                          "Air Marshal",
                          "Federal Aviation Administration",
                          "National Guard ",
                          "Emergency Management",
                          "U.S. Immigration and Customs Enforcement",
                          "United Nations"]

# %% [markdown]
# # Search Terms
#
# In this notebook we will search for the google trends topics for each DHS terms for both terrorism and domestic categories

# %%
import requests
import pandas as pd
import numpy as np

# %%
# Directory to save/read data
data_path = "data/"

# Read API_key (you need your own key for it to work)
with open(data_path+"API_key","r") as f:
    API_key = f.read()

# %%
base_request_prefix = "https://kgsearch.googleapis.com/v1/entities:search"

# %% [markdown]
# ### Create simple request to test functionality

# %%
params = {
    "query" : "iraq",
    "key"   : API_key,
    "limit" : 10,  
    "indent": True
}
r = requests.get(base_request_prefix, params = params)
entity = r.json()
print(r.url)
# Out:
# https://kgsearch.googleapis.com/v1/entities:search?query=iraq&key=AIzaSyBM4RZcG5Jfel949oWndgzq_rIq-4PI_N8&limit=10&indent=True

# %%
entity
# Out:
# {'@context': {'goog': 'http://schema.googleapis.com/',
#   'detailedDescription': 'goog:detailedDescription',
#   'EntitySearchResult': 'goog:EntitySearchResult',
#   '@vocab': 'http://schema.org/',
#   'kg': 'http://g.co/kg',
#   'resultScore': 'goog:resultScore'},
#  '@type': 'ItemList',
#  'itemListElement': [{'result': {'@type': ['Place',
#      'Country',
#      'DefenceEstablishment',
#      'AdministrativeArea',
#      'Thing'],
#     'description': 'Country in the Middle East',
#     'name': 'Iraq',
#     '@id': 'kg:/m/0d05q4',
#     'detailedDescription': {'articleBody': 'Iraq, officially the Republic of Iraq, is a country in Western Asia, bordered by Turkey to the north, Iran to the east, Kuwait to the southeast, Saudi Arabia to the south, Jordan to the southwest and Syria to the west. ',
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#      'url': 'https://en.wikipedia.org/wiki/Iraq'}},
#    '@type': 'EntitySearchResult',
#    'resultScore': 14626.021484375},
#   {'result': {'detailedDescription': {'url': 'https://en.wikipedia.org/wiki/Islamic_State_of_Iraq_and_the_Levant',
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#      'articleBody': 'The Islamic State of Iraq and the Levant, also known as the Islamic State of Iraq and Syria, officially known as the Islamic State and also known by its Arabic acronym Daesh, is a militant Islamist group and a former unrecognised proto-state that follows a fundamentalist, Salafi jihadist doctrine of Sunni Islam. '},
#     '@type': ['Organization', 'Thing'],
#     'name': 'Islamic State of Iraq and the Levant',
#     '@id': 'kg:/m/027x630'},
#    '@type': 'EntitySearchResult',
#    'resultScore': 1121.14111328125},
#   {'@type': 'EntitySearchResult',
#    'resultScore': 764.1942749023438,
#    'result': {'description': 'Football team',
#     'name': 'Iraq national football team',
#     '@id': 'kg:/m/040p3y',
#     '@type': ['SportsTeam', 'Organization', 'Thing'],
#     'detailedDescription': {'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#      'url': 'https://en.wikipedia.org/wiki/Iraq_national_football_team',
#      'articleBody': "The Iraq national football team represents Iraq in international football and is controlled by the Iraq Football Association, the governing body for football in Iraq. Most of Iraq's home matches are played at the Basra International Stadium.\n"}}},
#   {'@type': 'EntitySearchResult',
#    'resultScore': 557.6151123046875,
#    'result': {'name': 'Babylon',
#     '@type': ['City',
#      'Country',
#      'Place',
#      'LandmarksOrHistoricalBuildings',
#      'AdministrativeArea',
#      'Thing'],
#     'detailedDescription': {'articleBody': 'Babylon was the capital city of the ancient Babylonian empire, which itself is a term referring to either of two subsequent empires of the Mesopotamian area. ',
#      'url': 'https://en.wikipedia.org/wiki/Babylon',
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License'},
#     'description': 'Empire',
#     '@id': 'kg:/m/01cyh'}},
#   {'result': {'detailedDescription': {'url': 'https://en.wikipedia.org/wiki/Iran%E2%80%93Iraq_War',
#      'articleBody': 'The Iran–Iraq War was a protracted armed conflict that began on 22 September 1980 when Iraq invaded neighbouring Iran. The war lasted almost eight years, ending in a stalemate on 20 August 1988 when Iran accepted a UN-brokered ceasefire. ',
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License'},
#     '@type': ['Event', 'Thing'],
#     '@id': 'kg:/m/03vc6',
#     'description': 'Armed conflict',
#     'name': 'Iran–Iraq War'},
#    '@type': 'EntitySearchResult',
#    'resultScore': 396.8848571777344},
#   {'result': {'name': 'Karbala',
#     'detailedDescription': {'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#      'articleBody': 'Kerbala District is a district of the Karbala Governorate, Iraq.',
#      'url': 'https://en.wikipedia.org/wiki/Kerbala_District'},
#     'description': 'City in Iraq',
#     '@type': ['City', 'Place', 'Thing'],
#     '@id': 'kg:/m/01dyns'},
#    '@type': 'EntitySearchResult',
#    'resultScore': 297.4979248046875},
#   {'resultScore': 273.0928955078125,
#    'result': {'detailedDescription': {'url': 'https://en.wikipedia.org/wiki/Ur',
#      'articleBody': "Ur was an important Sumerian city-state in ancient Mesopotamia, located at the site of modern Tell el-Muqayyar in south Iraq's Dhi Qar Governorate. ",
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License'},
#     '@id': 'kg:/m/07w5c',
#     'description': 'State',
#     'name': 'Ur',
#     '@type': ['City', 'Country', 'Place', 'Thing']},
#    '@type': 'EntitySearchResult'},
#   {'result': {'detailedDescription': {'url': 'https://en.wikipedia.org/wiki/Erbil',
#      'articleBody': 'Erbil or Hawler, known in ancient history as Arbela, is the capital and most populated city in Kurdistan Region in Iraq. It has about 1.5 Million inhabitants, while Erbil Governorate has a permanent population of 2,932,800 as of 2020.\n',
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License'},
#     '@type': ['City', 'Place', 'Thing'],
#     'url': 'http://hawlergov.org/ku/index.php',
#     'name': 'Erbil',
#     '@id': 'kg:/m/03n7br',
#     'description': 'Capital of Iraqi Kurdistan'},
#    'resultScore': 252.9482574462891,
#    '@type': 'EntitySearchResult'},
#   {'resultScore': 170.2812347412109,
#    '@type': 'EntitySearchResult',
#    'result': {'description': 'Currency',
#     '@type': ['Thing'],
#     'detailedDescription': {'url': 'https://en.wikipedia.org/wiki/Iraqi_dinar',
#      'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#      'articleBody': 'The Iraqi dinar, although inflation has rendered the fils obsolete since 1990.'},
#     'name': 'Iraqi dinar',
#     '@id': 'kg:/m/01kpb3'}},
#   {'@type': 'EntitySearchResult',
#    'result': {'description': 'Basketball team',
#     '@type': ['SportsTeam', 'Organization', 'Thing'],
#     'detailedDescription': {'license': 'https://en.wikipedia.org/wiki/Wikipedia:Text_of_Creative_Commons_Attribution-ShareAlike_3.0_Unported_License',
#      'url': "https://en.wikipedia.org/wiki/Iraq_men's_national_basketball_team",
#      'articleBody': "The Iraq national basketball team represents Iraq in international basketball competitions.\nIt is one out of only two Arab nations to ever qualify for the Men's Basketball Tournament at the Summer Olympics."},
#     'name': "Iraq men's national basketball team",
#     '@id': 'kg:/m/02z33r8'},
#    'resultScore': 46.37569046020508}]}

# %% [markdown]
# ### Result explanation
#
# The response JSON gives a maximum of 10 corresponding entities. They are ordered by "resultScore: An indicator of how well the entity matched the request constraints". Therefore, we choose the first one which has the highest resultScore and we can recover "@id: The canonical URI for the entity". Then, we can select the correct identifier by spliting the result on ":" and taking the second element.
#
# Source: https://developers.google.com/knowledge-graph/reference/rest/v1

# %%
print(entity["itemListElement"][0]["result"]['@id'].split(":")[1])
# Out:
# /m/0d05q4

# %% [markdown]
# ### Create mapping from search query to Google Knowledge Graph Search Node

# %%
def create_search_terms_to_GKG_node_df(search_terms, domain_name, API_key):
    """Creates a dataframe mapping a list of search terms to their GKG node representation.
    We make the assumption that the first google result corresponds to the correct topic representation
    (has the highest resultScore).
    This assumption should hold for our project as the terms are not ambuiguous.
    The returned dataframe has attributes:
    {search_term, node_equivalent, domain_name}

    Args:
        search_terms (list[string]): List of all required search queries to map
        domain_name (str): domain of the search queries (ie. terrorims, domestic, top_30_terrorism)
        API_key (str): API key to use for the requests

    Returns:
        dataframe: dataframe mapping search term to their GKG node representation

    """

    # Create function which uses the GKG Api to find the corresponding node for one search query
    def map_search_term(search_term, API_key):
        """Maps one search query to the first google result search node representation"""
        
        # Create base request url
        base_request_prefix = "https://kgsearch.googleapis.com/v1/entities:search"

        # Create parameters for the request
        params = {
            "query" : search_term,
            "key"   : API_key,
            "limit" : 10, # min is 10 but we care only about the first search
            "indent": True
        }
        r = requests.get(base_request_prefix, params = params)
        
        # Find the Google Knowledge Graph Search entity id
        entity_id = r.json()["itemListElement"][0]["result"]['@id'].split(":")[1]
        # Find the Google Knowledge Graph Search entity name
        entity_name = r.json()["itemListElement"][0]["result"]['name']
        
        return (entity_id, entity_name)
    
    # Map search terms to entity id and name equivalent
    entities = [map_search_term(search_term, API_key) for search_term in search_terms]
    
    # Extract entity ids
    entity_ids = [entity[0] for entity in entities]
    
    # Extract entity names
    entity_names = [entity[1] for entity in entities]
    
    # Create domain column
    domain_column = [domain_name]*len(entities)
    
    # Create dictionary for the df
    data={
        "search_term" : search_terms,
        "entity_id"   : entity_ids,
        "entity_name" : entity_names,
        "domain_name" : domain_column
    }
    
    # return the mapping df
    return pd.DataFrame(data=data)

# %% [markdown]
# ### Terrorism dataset Mapping

# %%
terrorism_mapping_df = create_search_terms_to_GKG_node_df(terrorism_search_queries, "terrorism", API_key)
# Identifier for Google Knowledge Graph API (starting with "/g/") IDs starting with "/m/" are Freebase IDs

# %%
terrorism_mapping_df
# Out:
#                           search_term      entity_id  \
# 0                            Al-Qaeda        /m/0v74
# 1                           terrorism       /m/07jq_
# 2                              terror       /m/07jq_
# 3                              attack     /m/0gtxdb2
# 4                                iraq      /m/0d05q4
# 5                         afghanistan        /m/0jdd
# 6                                iran       /m/03shp
# 7                            Pakistan       /m/05sb1
# 8                                Agro      /m/019jkv
# 9             Environmental Terrorism     /m/02w1mcd
# 10                      Eco-Terrorism      /m/01s60b
# 11                Conventional Weapon      /m/02t93h
# 12                      Weapons Grade      /m/0blqm8
# 13                         Dirty Bomb       /m/0fjf_
# 14                 Nuclear Enrichment  /g/11k69f5spb
# 15                            Nuclear       /m/04xkp
# 16                    Chemical Weapon     /m/0bwkbcx
# 17                  Biological Weapon      /m/01xmw0
# 18                   Ammonium nitrate       /m/0ny03
# 19        Improvised Explosive Device      /m/01n8xw
# 20                         Abu Sayyaf        /m/0xq_
# 21                              Hamas       /m/03m6j
# 22                               FARC      /m/011ys5
# 23              Irish Republican Army       /m/05sz6
# 24             Euskadi ta Askatasuna        /m/02pvw
# 25                          Hezbollah       /m/03m7d
# 26                       Tamil Tigers       /m/04q9w
# 27                                PLO       /m/0jz65
# 28         Palestine Liberation Front      /m/01d_w8
# 29                           Car bomb      /m/014bmh
# 30                              Jihad       /m/0445s
# 31                            Taliban       /m/07jqh
# 32                     Suicide bomber  /g/11cr_hd3g5
# 33                     Suicide attack       /m/078f4
# 34  AL Qaeda in the Arabian Peninsula     /m/02psd87
# 35    Al Qaeda in the Islamic Maghreb     /m/02qr9gb
# 36          Tehrik-i-Taliban Pakistan     /m/04jhbb_
# 37                              Yemen      /m/01z88t
# 38                            Pirates      /m/01vksx
# 39                          Extremism      /m/027947
# 40                            Somalia       /m/06tgw
# 41                            Nigeria       /m/05cgv
# 42               Political radicalism     /m/03mhnhh
# 43                         Al-Shabaab     /m/027ggxz
# 44                        Nationalism       /m/05gd9
# 45                        Recruitment      /m/03nw7w
# 46                     Fundamentalism       /m/032b8
# 47                           Islamist      /m/02qs3j
#
#                                           entity_name domain_name
# 0                                            Al-Qaeda   terrorism
# 1                                           Terrorism   terrorism
# 2                                           Terrorism   terrorism
# 3                                     Attack on Titan   terrorism
# 4                                                Iraq   terrorism
# 5                                         Afghanistan   terrorism
# 6                                                Iran   terrorism
# 7                                            Pakistan   terrorism
# 8                                            Agronomy   terrorism
# 9                             Environmental terrorism   terrorism
# 10                                      Eco-terrorism   terrorism
# 11                                Conventional weapon   terrorism
# 12                     Weapons-grade nuclear material   terrorism
# 13                                         Dirty bomb   terrorism
# 14  International Conference on Nuclear Fuel Cycle...   terrorism
# 15                         Magnetic resonance imaging   terrorism
# 16                                    Chemical weapon   terrorism
# 17                      Biological Weapons Convention   terrorism
# 18                                   Ammonium nitrate   terrorism
# 19                        Improvised explosive device   terrorism
# 20                                         Abu Sayyaf   terrorism
# 21                                              Hamas   terrorism
# 22                                              Farce   terrorism
# 23                  Provisional Irish Republican Army   terrorism
# 24                                                ETA   terrorism
# 25                                          Hezbollah   terrorism
# 26                   Liberation Tigers of Tamil Eelam   terrorism
# 27                                               Plot   terrorism
# 28                       Palestinian Liberation Front   terrorism
# 29                                           Car bomb   terrorism
# 30                                              Jihad   terrorism
# 31                                            Taliban   terrorism
# 32                              Female suicide bomber   terrorism
# 33                                     Suicide attack   terrorism
# 34                  Al-Qaeda in the Arabian Peninsula   terrorism
# 35                    al-Qaeda in the Islamic Maghreb   terrorism
# 36                          Tehrik-i-Taliban Pakistan   terrorism
# 37                                              Yemen   terrorism
# 38  Pirates of the Caribbean: The Curse of the Bla...   terrorism
# 39                                          Extremism   terrorism
# 40                                            Somalia   terrorism
# 41                                            Nigeria   terrorism
# 42                                   Radical politics   terrorism
# 43                                         Al-Shabaab   terrorism
# 44                                        Nationalism   terrorism
# 45                                        Recruitment   terrorism
# 46                                     Fundamentalism   terrorism
# 47                                  Islamic terrorism   terrorism

# %% [markdown]
# ### Observation
#
# We spot two problems when we use the highest resultScore directly.
#
# 1. Some search terms might point to the same entity (ex: terror and terrorism both point to the "Terrorism" entity)
# 2. Some search terms point to a topic that does not correspond to the "Terrorism" domain (ex: attack points to "Attack on Titan" entity)
#
# ### Solutions
#
# The first problem can be solved by using only one of the duplicated enties. This should not lead to any problems since the topic itself encompasses both search terms.
#
# For the second problem we can chose to either delete it, individually look up the corresponding topic by using google trends directly or individually analyse the 10 returned entities to find the closest to the one we are looking for.
#
# ### Decision
#
# Looking up the corresponding topic on google trends individually for each missguided topic will lead to the closest topic to the search term we require. Indeed, on google trends when selecting a specific search term the related topics are offered. If no topic are found for this entity we will drop it otherwise we will replace the entry by the one provided by google trends.
#
# ### Problematic entries and replacement
#
# 3	attack:	/m/0gtxdb2	Attack on Titan	=> /g/11bc5q9v7r Attack
#
# 8	Agro:	/m/019jkv	Agronomy => No terrorism topics
#
# 14  Nuclear Enrichment:	/g/11k69f5spb	International Conference on Nuclear Fuel Cycle...=> No topics
#
# 15  Nuclear:	/m/04xkp	Magnetic resonance imaging => /m/05gpf Nuclear weapon
#
# 17  Biological Weapon:	/m/01xmw0	Biological Weapons Convention => /g/121x751y biological weapon
#
# 22	FARC:	/m/011ys5	Farce => /m/06hvg Revolutionary Armed Forces of Colombia—People's Army
#
# 32  Suicide bomber:	/g/11cr_hd3g5	Female suicide bomber => No suicide bomber topic
#
# 38  Pirates:	/m/01vksx	Pirates of the Caribbean: The Curse of the Bla... => No terrorism topics

# %%
def fix_topics(dataframe, id_replacement, name_replacement, topics_id_to_delete):
    """Fixes topic errors in the dataframe due to ambiguous seach terms, duplicates and non-existing topics.   

    Args:
        dataframe (dataframe): dataframe to fix topic. Requires "entity_name" and "entity_id" columns
        id_replacement (dict): dictionary mapping erronous entity id to correct id
        name_replacement (dict): dictionary mapping erronous entity name to correct name
        topics_to_delete (list(str)): List of all topics ids for which to delete the rows
    Returns:
        dataframe: dataframe with the erronous entries fixed
    """

    # Change required entries and leave the rest
    dataframe["entity_id"] = dataframe["entity_id"] \
                                    .apply(lambda x: id_replacement.get(x) if id_replacement.get(x) is not None else x)
    
    dataframe["entity_name"] = dataframe["entity_name"] \
                                    .apply(lambda x: name_replacement.get(x) if name_replacement.get(x) is not None else x)
    
    # Remove duplicate topics
    dataframe = dataframe.drop_duplicates(subset = ["entity_id", "entity_name"])
    
    # Remove topics that have no corresponding google trends topics
    mask = dataframe["entity_id"].apply(lambda x: x not in topics_id_to_delete)
    
    return dataframe[mask]

# %%
# Create id replacement dictionary
id_replacement = {
    "/m/0gtxdb2" : "/g/11bc5q9v7r",
    "/m/04xkp"   : "/m/05gpf",
    "/m/01xmw0"  : "/g/121x751y",
    "/m/011ys5"  : "/m/06hvg"
}

# Create name replacement dictionary
name_replacement = {
    "Attack on Titan" : "Attack",
    "Magnetic resonance imaging" : "Nuclear weapon",
    "Biological Weapons Convention" : "biological weapon",
    "Farce" : "Revolutionary Armed Forces of Colombia—People's Army"
}

# Create list of topics ids to delete
topics_id_to_delete = [
    "/g/11k69f5spb",
    "/g/11cr_hd3g5",
    "/m/01vksx"
]

# %%
# Fix ambiguous topics
terrorism_mapping_df = fix_topics(terrorism_mapping_df, id_replacement, name_replacement, topics_id_to_delete)

# %%
terrorism_mapping_df
# Out:
#                           search_term      entity_id  \
# 0                            Al-Qaeda        /m/0v74
# 1                           terrorism       /m/07jq_
# 3                              attack  /g/11bc5q9v7r
# 4                                iraq      /m/0d05q4
# 5                         afghanistan        /m/0jdd
# 6                                iran       /m/03shp
# 7                            Pakistan       /m/05sb1
# 8                                Agro      /m/019jkv
# 9             Environmental Terrorism     /m/02w1mcd
# 10                      Eco-Terrorism      /m/01s60b
# 11                Conventional Weapon      /m/02t93h
# 12                      Weapons Grade      /m/0blqm8
# 13                         Dirty Bomb       /m/0fjf_
# 15                            Nuclear       /m/05gpf
# 16                    Chemical Weapon     /m/0bwkbcx
# 17                  Biological Weapon    /g/121x751y
# 18                   Ammonium nitrate       /m/0ny03
# 19        Improvised Explosive Device      /m/01n8xw
# 20                         Abu Sayyaf        /m/0xq_
# 21                              Hamas       /m/03m6j
# 22                               FARC       /m/06hvg
# 23              Irish Republican Army       /m/05sz6
# 24             Euskadi ta Askatasuna        /m/02pvw
# 25                          Hezbollah       /m/03m7d
# 26                       Tamil Tigers       /m/04q9w
# 27                                PLO       /m/0jz65
# 28         Palestine Liberation Front      /m/01d_w8
# 29                           Car bomb      /m/014bmh
# 30                              Jihad       /m/0445s
# 31                            Taliban       /m/07jqh
# 33                     Suicide attack       /m/078f4
# 34  AL Qaeda in the Arabian Peninsula     /m/02psd87
# 35    Al Qaeda in the Islamic Maghreb     /m/02qr9gb
# 36          Tehrik-i-Taliban Pakistan     /m/04jhbb_
# 37                              Yemen      /m/01z88t
# 39                          Extremism      /m/027947
# 40                            Somalia       /m/06tgw
# 41                            Nigeria       /m/05cgv
# 42               Political radicalism     /m/03mhnhh
# 43                         Al-Shabaab     /m/027ggxz
# 44                        Nationalism       /m/05gd9
# 45                        Recruitment      /m/03nw7w
# 46                     Fundamentalism       /m/032b8
# 47                           Islamist      /m/02qs3j
#
#                                           entity_name domain_name
# 0                                            Al-Qaeda   terrorism
# 1                                           Terrorism   terrorism
# 3                                              Attack   terrorism
# 4                                                Iraq   terrorism
# 5                                         Afghanistan   terrorism
# 6                                                Iran   terrorism
# 7                                            Pakistan   terrorism
# 8                                            Agronomy   terrorism
# 9                             Environmental terrorism   terrorism
# 10                                      Eco-terrorism   terrorism
# 11                                Conventional weapon   terrorism
# 12                     Weapons-grade nuclear material   terrorism
# 13                                         Dirty bomb   terrorism
# 15                                     Nuclear weapon   terrorism
# 16                                    Chemical weapon   terrorism
# 17                                  biological weapon   terrorism
# 18                                   Ammonium nitrate   terrorism
# 19                        Improvised explosive device   terrorism
# 20                                         Abu Sayyaf   terrorism
# 21                                              Hamas   terrorism
# 22  Revolutionary Armed Forces of Colombia—People'...   terrorism
# 23                  Provisional Irish Republican Army   terrorism
# 24                                                ETA   terrorism
# 25                                          Hezbollah   terrorism
# 26                   Liberation Tigers of Tamil Eelam   terrorism
# 27                                               Plot   terrorism
# 28                       Palestinian Liberation Front   terrorism
# 29                                           Car bomb   terrorism
# 30                                              Jihad   terrorism
# 31                                            Taliban   terrorism
# 33                                     Suicide attack   terrorism
# 34                  Al-Qaeda in the Arabian Peninsula   terrorism
# 35                    al-Qaeda in the Islamic Maghreb   terrorism
# 36                          Tehrik-i-Taliban Pakistan   terrorism
# 37                                              Yemen   terrorism
# 39                                          Extremism   terrorism
# 40                                            Somalia   terrorism
# 41                                            Nigeria   terrorism
# 42                                   Radical politics   terrorism
# 43                                         Al-Shabaab   terrorism
# 44                                        Nationalism   terrorism
# 45                                        Recruitment   terrorism
# 46                                     Fundamentalism   terrorism
# 47                                  Islamic terrorism   terrorism

# %% [markdown]
# ### Domestic dataset Mapping

# %%
domestic_mapping_df = create_search_terms_to_GKG_node_df(domestic_search_queries, "domestic", API_key)

# %%
domestic_mapping_df
# Out:
#                                   search_term    entity_id  \
# 0             Department of Homeland Security     /m/0fytk
# 1         Federal Emergency Management Agency     /m/0js8z
# 2                                 Coast Guard     /m/07xhy
# 3              Customs and Border Protection     /m/038r8p
# 4                               Border patrol    /m/02qtlv
# 5                              Secret Service     /m/0fynw
# 6                   Bureau of Land Management     /m/0f4r5
# 7                            Homeland defense  /g/1210mblq
# 8                                   Espionage     /m/02vnz
# 9                               Task Force 88   /m/04yd3hg
# 10                Central Intelligence Agency    /m/0d6qjf
# 11                              Fusion center   /m/02p7v5m
# 12                                        DEA    /m/012qj2
# 13                  Secure Border Initiative    /m/02q3_66
# 14            Federal Bureau of Investigation     /m/02_1m
# 15   Alcohol and Tobacco Tax and Trade Bureau    /m/020plr
# 16  U.S. Citizenship and Immigration Services    /m/021psw
# 17               Federal Air Marshal Service     /m/03__hw
# 18     Transportation Security Administration    /m/0179dd
# 20            Federal Aviation Administration     /m/02_hj
# 21                            National Guard      /m/09gs3
# 22                       Emergency Management    /m/052yrz
# 23   U.S. Immigration and Customs Enforcement    /m/01fp_h
# 24                             United Nations     /m/07t65
#
#                                           entity_name domain_name
# 0       United States Department of Homeland Security    domestic
# 1                 Federal Emergency Management Agency    domestic
# 2                           United States Coast Guard    domestic
# 3                  U.S. Customs and Border Protection    domestic
# 4                         United States Border Patrol    domestic
# 5                        United States Secret Service    domestic
# 6                           Bureau of Land Management    domestic
# 7                                    Homeland defense    domestic
# 8                                           Espionage    domestic
# 9   Joint Special Operations Command Task Force in...    domestic
# 10                        Central Intelligence Agency    domestic
# 11                                      Fusion center    domestic
# 12                    Drug Enforcement Administration    domestic
# 13                           Secure Border Initiative    domestic
# 14                    Federal Bureau of Investigation    domestic
# 15           Alcohol and Tobacco Tax and Trade Bureau    domestic
# 16  United States Citizenship and Immigration Serv...    domestic
# 17                        Federal Air Marshal Service    domestic
# 18             Transportation Security Administration    domestic
# 20                    Federal Aviation Administration    domestic
# 21                       United States National Guard    domestic
# 22                               Emergency management    domestic
# 23           U.S. Immigration and Customs Enforcement    domestic
# 24                                     United Nations    domestic

# %% [markdown]
# ### Observation
#
# There is only one probleme here:
#
# Secret Service	/m/0y4n5ll	Kingsman: The Secret Service => /m/0fynw United States Secret Service
#
# We can observe that most topics are related to the US but this is expected because we use the DHS (Department of Homeland Security) keywords for domestic security.

# %%
# Create id replacement dictionary
domestic_id_replacement = {
    "/m/0y4n5ll" : "/m/0fynw",
}

# Create name replacement dictionary
domestic_name_replacement = {
    "Kingsman: The Secret Service" : "United States Secret Service"
}

# %%
# Fix ambiguous topics
domestic_mapping_df = fix_topics(domestic_mapping_df, domestic_id_replacement, domestic_name_replacement, [])

# %% [markdown]
# ### Top-30 terrorism dataset Mapping

# %%
top_30_terrorism_mapping_df = create_search_terms_to_GKG_node_df(top_30_terrorism_search_queries, "top_30_terrorism", API_key)

# %%
top_30_terrorism_mapping_df
# Out:
#                           search_term    entity_id  \
# 0                            Al Qaeda      /m/0v74
# 1                           Terrorism     /m/07jq_
# 3             Environmental Terrorism   /m/02w1mcd
# 4                       Eco-terrorism    /m/01s60b
# 5                 Conventional Weapon    /m/02t93h
# 6                       Weapons Grade    /m/0blqm8
# 7                          Dirty Bomb     /m/0fjf_
# 9                             Nuclear     /m/05gpf
# 10                    Chemical Weapon   /m/0bwkbcx
# 11                  Biological Weapon  /g/121x751y
# 12        Improvised Explosive Device    /m/01n8xw
# 13                         Abu Sayyaf      /m/0xq_
# 14                               FARC     /m/06hvg
# 15             Euskadi ta Askatasuna      /m/02pvw
# 16                          Hezbollah     /m/03m7d
# 17         Palestine Liberation Front    /m/01d_w8
# 18                           Car bomb    /m/014bmh
# 19                              Jihad     /m/0445s
# 20                            Taliban     /m/07jqh
# 22                     Suicide attack     /m/078f4
# 23  AL Qaeda in the Arabian Peninsula   /m/02psd87
# 24    Al Qaeda in the Islamic Maghreb   /m/02qr9gb
# 25          Tehrik-i-Taliban Pakistan   /m/04jhbb_
# 26               Political radicalism   /m/03mhnhh
# 27                         Al-Shabaab   /m/027ggxz
# 28                        Recruitment    /m/03nw7w
# 29                           Islamist    /m/02qs3j
#
#                                           entity_name       domain_name
# 0                                            Al-Qaeda  top_30_terrorism
# 1                                           Terrorism  top_30_terrorism
# 3                             Environmental terrorism  top_30_terrorism
# 4                                       Eco-terrorism  top_30_terrorism
# 5                                 Conventional weapon  top_30_terrorism
# 6                      Weapons-grade nuclear material  top_30_terrorism
# 7                                          Dirty bomb  top_30_terrorism
# 9                                      Nuclear weapon  top_30_terrorism
# 10                                    Chemical weapon  top_30_terrorism
# 11                                  biological weapon  top_30_terrorism
# 12                        Improvised explosive device  top_30_terrorism
# 13                                         Abu Sayyaf  top_30_terrorism
# 14  Revolutionary Armed Forces of Colombia—People'...  top_30_terrorism
# 15                                                ETA  top_30_terrorism
# 16                                          Hezbollah  top_30_terrorism
# 17                       Palestinian Liberation Front  top_30_terrorism
# 18                                           Car bomb  top_30_terrorism
# 19                                              Jihad  top_30_terrorism
# 20                                            Taliban  top_30_terrorism
# 22                                     Suicide attack  top_30_terrorism
# 23                  Al-Qaeda in the Arabian Peninsula  top_30_terrorism
# 24                    al-Qaeda in the Islamic Maghreb  top_30_terrorism
# 25                          Tehrik-i-Taliban Pakistan  top_30_terrorism
# 26                                   Radical politics  top_30_terrorism
# 27                                         Al-Shabaab  top_30_terrorism
# 28                                        Recruitment  top_30_terrorism
# 29                                  Islamic terrorism  top_30_terrorism

# %% [markdown]
# ### Observation
#
# Since the original search are a subset from the terrorism domain we need to fix the same problems.

# %%
# Fix ambiguous topics
top_30_terrorism_mapping_df = fix_topics(top_30_terrorism_mapping_df, id_replacement, name_replacement, topics_id_to_delete)

# %% [markdown]
# ### Create a dataframe with all mappings

# %%
all_mappings = [terrorism_mapping_df, domestic_mapping_df, top_30_terrorism_mapping_df]
# Concatenate all mappings into one dataframe
all_mappings_df = pd.concat(all_mappings).reset_index().drop(columns=['index'])
all_mappings_df
# Out:
#                   search_term      entity_id                entity_name  \
# 0                    Al-Qaeda        /m/0v74                   Al-Qaeda
# 1                   terrorism       /m/07jq_                  Terrorism
# 2                      attack  /g/11bc5q9v7r                     Attack
# 3                        iraq      /m/0d05q4                       Iraq
# 4                 afghanistan        /m/0jdd                Afghanistan
# ..                        ...            ...                        ...
# 90  Tehrik-i-Taliban Pakistan     /m/04jhbb_  Tehrik-i-Taliban Pakistan
# 91       Political radicalism     /m/03mhnhh           Radical politics
# 92                 Al-Shabaab     /m/027ggxz                 Al-Shabaab
# 93                Recruitment      /m/03nw7w                Recruitment
# 94                   Islamist      /m/02qs3j          Islamic terrorism
#
#          domain_name
# 0          terrorism
# 1          terrorism
# 2          terrorism
# 3          terrorism
# 4          terrorism
# ..               ...
# 90  top_30_terrorism
# 91  top_30_terrorism
# 92  top_30_terrorism
# 93  top_30_terrorism
# 94  top_30_terrorism
#
# [95 rows x 4 columns]

# %%
# Save dataframe to pickle
all_mappings_df.to_pickle(data_path+"mapping.pkl")
