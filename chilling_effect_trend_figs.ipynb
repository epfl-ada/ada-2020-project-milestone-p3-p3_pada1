# %% [markdown]
# # Milestone P4 - A comparative approach on chilling effect, from Wikipedia to Google Trend
#
# ## Course CS-401 - Applied Data Analysis
#
# ### Instructor : [Robert West](https://dlab.epfl.ch/people/west/)
#
# ### Author :
# - **Chraibi Ghali**
#     SCIPER: 262251
# - **Jesslen Artur**
#     SCIPER: 270642
# - **Michels Luc**
#     SCIPER: 273666
#
# #### Due date: 18 Dec 2020

# %% [markdown]
# ### Imports

# %%
import matplotlib.pyplot as plt
import scipy.stats as stats
import pandas as pd
import numpy as np
import seaborn as sn

from os import path
import json
import requests

from helper import *

# %% [markdown]
# ---
# ## Context
#
# In the paper *Chilling effects: Online surveillance and Wikipedia use*, Dr. Penney present an analysis showing that the revelation of Snowden in June 2013 has caused a chilling effect on Wikipedia user. According to his study not only the revelation suddenly discouraged Wikipedia users to look for privacy-sensitive Wikipedia articles, but the effect also had a long term impact.
#
# In this study, we reproduce Dr. Penney's experiment on Google to verify if we also observe a chilling effect on a more global context.

# %% [markdown]
# ---
# ## Scrapping of the data
#
# **> From Wikipedia to google trends**
#
# By using Google Trends, we can get location-specific answers and also use language agnostic requests through topics. However, some limitations were introduced as google trends does not provide absolute article views numbers, but instead gives normalized results based on the highest search count in the specified timeframe and location ([2]).
#
# Our goal is to obtain the equivalent in google trends of the following datasets from the paper:
#     - Terrorism Articles (& Top 30 Terrorism Articles)
#     - Domestic Articles
#     - Infrastructure Articles
#
# In this section, we will explain how we tackled these problems and obtained our google trends dataframes.
#
# **Step 1: Article to Search term**
#
#
#
# **Step 2: Search term to topic**
#
#
#
# **Step 3: Google Trends Anchor Bank**
#
# Now that we have topics we can directly use it to query any google trends API ([3]). However, as explained above, the results obtained are normalized and we can compare only up to 5 queries ([2]). This means that we cannot compare our results together as we don’t have the absolute values for each query and we have a minimum of 24 topics to compare.
#
# We can use the GTab API to bypass this problem. Indeed, GTab creates an offline anchor bank with a wide range of queries and one reference query. All subsequent queries are then compared to the closest stored query with a binary search which is in turn compared to the reference query. Therefore, all queries we make are relative to the reference query which means we can compare our queries together and we also remove rounding errors in the event we would be comparing topics with too large differences in popularity ([8]).
#
# **Step 4: Creating the dataframes**
#
# We now have all the required tools for creating the dataframes. We start by creating the required anchor banks for GTab. We create two anchor banks with a US search location.
# Indeed, the original terms for the queries come from the DHS, the Department of Homeland Security. The terms which originate from this institution are mostly directed towards the American population. Most notably, the “domestic” category mainly uses US organisations (ex: DHS, FBI, CIA, etc).
# Then we chose two timeframes: one for the paper timeframe (2012-01-01 -> 2014-08-31) and one that goes until the end of November 2020 (2012-01-01 -> 2020-11-30). Afterwards, we query google trends using the GTab API and the corresponding anchor bank.
#
# The data frame created has following attributes:
#
# | Name | Description |
# | ----------------- | ---------------- |
# | Date          | Starting day of the week where the data is aggregated |
# | max_ratio     | Calibrated value based on the reference query of the anchor bank (most popular query of the anchor bank) |
# | max_ratio_hi  | Low error bound determined by gtab |
# | max_ratio_lo  | High error bound determined by gtab |
# | article_name  | Name of the original DHS term |
#
#
#
# [2]: https://support.google.com/trends/answer/4365533?hl=en
#
#
# [8]: https://arxiv.org/abs/2007.13861

# %%
## Constants
data_path = "data/"

# If true, create the mapping between search term and topic (mapping.pkl)
MAPPING = False

# If true, create the anchor bank and the dataframes (in pickle format)
CREATE_DATAFRAMES = False

# %% [markdown]
# ### Step 1: Article to Search term
#
# To reproduce the results obtained by Dr. Jonathon W. Penney ([9]), we first need to translate the terms from their respective DHS categories into google search terms. In most cases we can use the DHS terms directly. However if there are several terms to translate we use the one closest to the wikipedia article chosen by Dr. Penney (ex: “Agent/Espionage” becomes “Espionage”).
#
# [9]: https://papers.ssrn.com/sol3/papers.cfm?abstract_id=2769645

# %%
# Load the search terms from pre-filled file & print them
search_queries = load_pickle(data_path + 'search_queries.pkl')
for key, value in search_queries.items():
    print(f"{key}:\n{value}\n")
# Out:
# terrorism:
# ['Al-Qaeda', 'terrorism', 'terror', 'attack', 'iraq', 'afghanistan', 'iran', 'Pakistan', 'Agro', 'Environmental Terrorism', 'Eco-Terrorism', 'Conventional Weapon', 'Weapons Grade', 'Dirty Bomb', 'Nuclear Enrichment', 'Nuclear', 'Chemical Weapon', 'Biological Weapon', 'Ammonium nitrate', 'Improvised Explosive Device', 'Abu Sayyaf', 'Hamas', 'FARC', 'Irish Republican Army', 'Euskadi ta Askatasuna ', 'Hezbollah', 'Tamil Tigers', 'Palestine Liberation Organization', 'Palestine Liberation Front', 'Car bomb', 'Jihad', 'Taliban', 'Suicide bomber', 'Suicide attack', 'AL Qaeda in the Arabian Peninsula', 'Al Qaeda in the Islamic Maghreb', 'Tehrik-i-Taliban Pakistan', 'Yemen', 'Pirates', 'Extremism', 'Somalia', 'Nigeria', 'Political radicalism', 'Al-Shabaab', 'Nationalism', 'Recruitment', 'Fundamentalism', 'Islamist']
#
# top_30_terrorism:
# ...

# %% [markdown]
# ### Step 2: Search term to topic

# %% [markdown]
# Topics “are a group of terms that share the same concept in any language” ([4]) . (Which is particularly relevant when studying a multicultural country like U.S.A)
#
# Now that we have the search terms, we want to use the topics they represent. Indeed, using the DHS categories terms directly would probably yield incorrect results. For example, if we compare the interests for the search terms “Federal Bureau of Investigation” (the official term used by Dr. Penney) and “FBI” (its more commun abreviation), we see that almost every internet surfers use the latter ([6]). However for our analysis, both should point to the same entity. This is why, we use freebase IDs which regroups the terms with the same meaning together and corresponds to the “topics” in google trends (e.g. */m/02_1m* in the following ([3]), as shown in the URL).
#
# However, the freebase API is no longer usable ([5]). We have to pass through the Google Knowledge Graph Search API instead. This API lets us search for all entities in the Google Knowledge graph and gives us the entities closest to the search term we input. Each entity has a “resultScore:	An indicator of how well the entity matched the request constraints.” ([7]). Then we can parse the best entity for its corresponding freebase id (sometimes GKG id ([1]).
# However, by choosing the entity with the highest resultScore we make the assumption none of our DHS terms are ambiguous and the closest match will always be the correct topic. This holds for most DHS terms, but it is not true for all of them. This is why, we decide to individually fix those mismatched topics by finding the correct topic on Google trends or by dropping the term if no such topic exists. Also if two search terms points to the same topic, we only keep one (e.g. both “terror”  and “terrorism” point to the "Terrorism" entity so we kept only “terrorism”).
#
# Here is the full list of the replacements we make:
#
# |------------------- Original Term ------------------- |------------------ Mismatched topic *(Terrorism)* ------------------- |----------------------------- Replaced topic -----------------------------|
# | --------------------- | ------------------------------------------------- | ------ |
# | attack                | Attack on Titan                                   | Attack |
# | Agro                  | Agronomy                                          | No terrorism topic found |
# | Nuclear Enrichment    | International Conference on Nuclear Fuel Cycle…   | No terrorism topic found |
# | Nuclear               | Magnetic resonance imaging                        | Nuclear weapon |
# | Biological Weapon     | Biological Weapons Convention                     | biological weapon |
# | FARC                  | Farce                                             | Revolutionary Armed Forces of Colombia—People's Army |
# | Suicide bomber        | Female suicide bomber                             | No suicide bomber topic found |
# | Pirates               | Pirates of the Caribbean: The Curse of the Bla…   | No terrorism topic found |
#
# |------------------- Original Term ------------------- |------------------- Mismatched topic *(Domestic)* ------------------- |----------------------------- Replaced topic ----------------------------|
# | --------------------- | ------------------------------------------------- | ------ |
# | Secret Service        | Kingsman: The Secret Service                      | United States Secret Service |
# | Agro                  | Agronomy                                          | Agro-terrorism |
#
#
# |------------------- Original Term ------------------- |------------------- Mismatched topic *(Infrastructure)* ------------- |----------------------------- Replaced topic ----------------------------|
# | --------------------- | ------------------------------------------------- | ------ |
# | Telecommunication                 | Etisalat                                         | Telecommunications|
# | Metro                 | Metronidazole                                         | Rapid transit |
# | Port Authority                 | Port Authority of Allegheny County                                         | Port authority |
# | Power                 | Project Power                                         | Power |
# | Failure                 | Bankruptcy                                         | Failure |
# | NBIC                 | Narragansett Bay Insurance Company                                         | No infrastructure topic found |
# | Power grid                  | power grid of India                                         | No infrastructure topic found |
# | Smart                 | smartwatch                                         | No infrastructure topic found |
# | Port                 | Portugal                                         | No infrastructure topic found |
#
#
# |------------------- Original Term ------------------- |------------------- Mismatched topic *(Popular)* --------------------- |----------------------------- Replaced topic -----------------------------|
# | --------------------- | ------------------------------------------------- | ------ |
# | One Direction                | One Direction: This Is Us                                        | One Direction|
# | List of Bollywood Films 2013                 | Amitabh Bachchan                                         | Bollywood|
# | Ebola virus disease                 | Ebola virus disease treatment research                                      | Ebola|
# | Deaths in 2012/2013/2014                | Deathstroke                                        | Death|
#
#
#
# When using the GTab API (explained in next section), some of our queries returned with “bad response”. We also decide to drop these topics as there were no suitable replacement topics.
#
# All search queries and their relevant topics are stored in data/mapping.pkl.
#
# [1]: https://searchengineland.com/laymans-visual-guide-googles-knowledge-graph-search-api-241935
#
# [3]: https://trends.google.com/trends/explore?geo=US&q=%2Fm%2F02_1m
#
# [4]: https://support.google.com/trends/answer/4359550
#
# [5]: https://developers.google.com/freebase/v1/search
#
# [6]: https://trends.google.com/trends/explore?geo=US&q=Federal%20Bureau%20of%20Investigation,fbi
#
# [7]: https://developers.google.com/knowledge-graph/reference/rest/v1

# %%
if MAPPING:
    # Terrorism dataset Mapping
    terrorism_mapping_df = create_search_terms_to_GKG_node_df(search_queries['terrorism'], 
                                                              "terrorism", 
                                                              API_key)
    
    top_30_terrorism_mapping_df = create_search_terms_to_GKG_node_df(search_queries['top_30_terrorism'], 
                                                                     "top_30_terrorism", 
                                                                     API_key)
    
    # Create id replacement dictionary
    id_replacement = {
        "/m/0gtxdb2" : "/g/11bc5q9v7r",
        "/m/04xkp"   : "/m/05gpf",
        "/m/01xmw0"  : "/g/121x751y",
        "/m/011ys5"  : "/m/06hvg",
        "/m/019jkv"  : "/m/0gggw2"
    }

    # Create name replacement dictionary
    name_replacement = {
        "Attack on Titan" : "Attack",
        "Magnetic resonance imaging" : "Nuclear weapon",
        "Biological Weapons Convention" : "biological weapon",
        "Farce" : "Revolutionary Armed Forces of Colombia—People's Army",
        "Agronomy" : "Agro-terrorism"
    }

    # Create list of topics ids to delete
    topics_id_to_delete = [
        "/g/11k69f5spb",
        "/g/11cr_hd3g5",
        "/m/01vksx",
        "/m/0jz65"
    ]
    
    # Fix ambiguous topics
    terrorism_mapping_df = fix_topics(terrorism_mapping_df, 
                                      id_replacement, 
                                      name_replacement, 
                                      topics_id_to_delete)
    
    top_30_terrorism_mapping_df = fix_topics(top_30_terrorism_mapping_df, 
                                             id_replacement, 
                                             name_replacement, 
                                             topics_id_to_delete)

# %%
if MAPPING:
    # Security dataset Mapping
    domestic_mapping_df = create_search_terms_to_GKG_node_df(search_queries['domestic'], "domestic", API_key)
    
    # Create id replacement dictionary
    domestic_id_replacement = { "/m/0y4n5ll" : "/m/0fynw"}
    
    # Create name replacement dictionary
    domestic_name_replacement = {"Kingsman: The Secret Service" : "United States Secret Service"}
    
    # Fix ambiguous topics
    domestic_mapping_df = fix_topics(domestic_mapping_df, domestic_id_replacement, domestic_name_replacement, [])

# %%
if MAPPING:
    # Infrastructure dataset Mapping
    infrastructure_mapping_df = create_search_terms_to_GKG_node_df(search_queries['infrastructure'], 
                                                                   "infrastructure", 
                                                                   API_key)
    
    # Create id replacement dictionary
    id_replacement = {
        "/m/02g57n" : "/m/029g_vk",
        "/m/01trbt" : "/m/0195fx",
        "/m/06prnn" : "/m/025ssc5",
        "/g/11gnsngh28" : "/m/061ln",
        "/m/01hhz" : "/m/0bm6b",
    }
    
    # Create name replacement dictionary
    name_replacement = {
        "Etisalat" : "Telecommunications",
        "Metronidazole" : "Rapid transit",
        "Port Authority of Allegheny County" : "Port authority",
        "Project Power" : "Power",
        "Bankruptcy" : "Failure",        
    }
    
    # Create list of topics ids to delete
    topics_id_to_delete = {
        "/g/11dxq163st", # Narragansett Bay Insurance Company
        "/m/07pk20", # power grid of India
        "/m/05r4w", # Portugual
        "/m/0280wht" # smartwatch
    }
    
    # Fix ambiguous topics
    infrastructure_mapping_df = fix_topics(infrastructure_mapping_df, id_replacement, name_replacement, topics_id_to_delete)

# %%
if MAPPING:
    # Save all mappings in one pickle file
    all_mappings = [terrorism_mapping_df, domestic_mapping_df, top_30_terrorism_mapping_df]
    
    # Concatenate all mappings into one dataframe
    all_mappings_df = pd.concat(all_mappings).reset_index(drop=True)
    
    # Save dataframe to pickle
    all_mappings_df.to_pickle(data_path+"mapping.pkl")

# %% [markdown]
# #### Step 3 & 4: Google Trends Anchor Bank and creation of the dataframes

# %%
def create_dataframe(domain_name, geo, t):
    """
    Creates a dataframe concatenating all search queries interest over time data from google
    trends for one domain. The search queries will use the corresponding topics to the DHS category for the domain.
    Prints parametters of queries who failed.
    The returned dataframe has attributes:
    {date, max_ratio, max_ratio_hi, max_ratio_l, article_name, topic_name, topic_id, geo}

    Args:
        domain_name (str): domain of the search queries (ie. terrorims, domestic, top_30_terrorism)       
        geo (str): geolocalisation of the search query (Two Uppercase letter (ex: US, CH...) or "" for worldwide)
        t (GTAB): GoogleTrendsAnchorBank to use for the queries it needs to be consistent with the geo parameter

    Returns:
        dataframe: dataframe concatenating all search queries interest over time data from google trends

    """
    mapping_df = load_pickle(data_path+"mapping.pkl")
    
    # Get the list of the article names of this domain 
    topic_queries_articles = mapping_df[mapping_df["domain_name"] == domain_name]["search_term"].tolist()
    # Get the list of topic ids of this domain 
    topic_queries_ids = mapping_df[mapping_df["domain_name"] == domain_name]["entity_id"].tolist()
    # Get the list of topic names of this domain 
    topic_queries_name = mapping_df[mapping_df["domain_name"] == domain_name]["entity_name"].tolist()
    
    # For each search query freebase id create the corresponding interest over time google trends data
    all_interest_over_time_dfs = [t.new_query(search_query) for search_query in topic_queries_ids]
    
    # Find all queries who succeeded                 
    successful_queries = [type(df) != type(-1) for df in all_interest_over_time_dfs]
    
    df_to_concatenate = []
    # Append the name and location to all dataframes
    for i, df in enumerate(all_interest_over_time_dfs):
        
        # Was it a successful query
        if successful_queries[i]:
            
            # Add the article name collumn 
            df["article_name"] = [topic_queries_articles[i]]*len(df)
            # Add the topic name collumn 
            df["topic_id"] = [topic_queries_ids[i]]*len(df)
            # Add the topic id collumn 
            df["topic_name"] = [topic_queries_name[i]]*len(df)
            # Add the localisation collumn
            df["geo"] = ["worldwide" if geo == "" else geo]*len(df)
            
            df_to_concatenate.append(df)
            
        # If not we print the parametters that failed
        else:
            print("Found a failed query")
            print(f"Article name: {topic_queries_articles[i]}")
            print(f"Topic name: {topic_queries_name[i]}")
            print(f"Topic id: {topic_queries_ids[i]}")
    
    # Concatenate all dfs into one centrale one
    return pd.concat(df_to_concatenate).reset_index()
    
def get_topics(domain_name, data_path):
    """Gives the list of all topics corresponding to the search queries for the specific domain.
    
    Args:
         domain_name (str): domain name of the search queries (i.e: terrorism, domestic, top_30_terrorism)
         data_path (str): directory path containing the mapping pickle file 
    
    Returns:
        list of all topics for this domain
    """
    mapping_df = load_pickle(data_path+"mapping.pkl")
    
    return mapping_df[mapping_df["domain_name"] == domain_name]["entity_id"].tolist()

# %%
if CREATE_DATAFRAMES:
    # We choose the US geolocalisation because categories are from the DHS
    for geo in ["US"]:

        # Create time frame corresponding to the paper study
        start_timeframe = "2012-01-01"
        end_timeframe   = "2014-08-31"

        t = create_and_set_gtab(start_timeframe, end_timeframe, geo)

        # Create terrorism dataframe
        terrorism_df = create_dataframe("terrorism", geo, t)
        # Create domestic dataframe
        domestic_df = create_dataframe("domestic", geo, t)
        # Create top-30 terrorism dataframe
        top_30_terrorism_df = create_dataframe("top_30_terrorism", geo, t)
        # Save dataframes to pickle
        terrorism_df.to_pickle(data_path+f"terrorism_{geo}.pkl")
        domestic_df.to_pickle(data_path+f"domestic_{geo}.pkl")
        top_30_terrorism_df.to_pickle(data_path+f"top_30_terrorism_{geo}.pkl")
        
        # ---------------------------------------------------------------

        # Set start to paper start timeframe and end to present time (Stop at November 2020)
        start_timeframe = "2012-01-01"
        end_timeframe   = "2020-11-30"

        t = create_and_set_gtab(start_timeframe, end_timeframe, geo)

        # Create terrorism dataframe
        terrorism_df = create_dataframe("terrorism", geo, t)
        # Create domestic dataframe
        domestic_df = create_dataframe("domestic", geo, t)
        # Create top-30 terrorism dataframe
        top_30_terrorism_df = create_dataframe("top_30_terrorism", geo, t)
        # Save dataframe to pickle
        terrorism_df.to_pickle(data_path+f"terrorism_present_{geo}.pkl")
        domestic_df.to_pickle(data_path+f"domestic_present_{geo}.pkl")
        top_30_terrorism_df.to_pickle(data_path+f"top_30_terrorism_present_{geo}.pkl")

# %%
if CREATE_DATAFRAMES:
    # We choose the US geolocalisation because categories are from the DHS
    for geo in ["US"]:

        # Create time frame corresponding to the paper study
        start_timeframe = "2012-01-01"
        end_timeframe   = "2014-08-31"

        t = create_and_set_gtab(start_timeframe, end_timeframe, geo)

        # Create infrastructure dataframe
        infrastructure_df = create_dataframe("infrastructure", geo, t)
        # Create popular dataframe
        popular_df = create_dataframe("popular", geo, t)

        # Save dataframes to pickle
        infrastructure_df.to_pickle(data_path+f"infrastructure_{geo}.pkl")
        popular_df.to_pickle(data_path+f"popular_{geo}.pkl")

# %% [markdown]
# ---
# ### Replicate the experiment of the paper

# %% [markdown]
# #### Load data

# %%
data_path = 'data/'

if path.exists(data_path):
    terrorism_df = load_pickle(data_path+"terrorism_US.pkl")
    domestic_df = load_pickle(data_path+"domestic_US.pkl")
    terrorism30_df = load_pickle(data_path+"top_30_terrorism_US.pkl")
    popular_df = load_pickle(data_path+"popular_US.pkl")
    infrastructure_df = load_pickle(data_path+"infrastructure_US.pkl")  
else:
    raise NotADirectoryError

# %%
columns_of_interest = ['date', 'max_ratio', 'topic_name']
terrorism_df = terrorism_df[columns_of_interest]
terrorism30_df = terrorism30_df[columns_of_interest]
domestic_df = domestic_df[columns_of_interest]
popular_df = popular_df[columns_of_interest]
infrastructure_df = infrastructure_df[columns_of_interest]

# %%
print(terrorism_df.shape)
terrorism_df.head(5)
# Out:
# (6020, 3)
#         date  max_ratio topic_name
# 0 2012-01-01   1.033386   Al-Qaeda
# 1 2012-01-08   1.351351   Al-Qaeda
# 2 2012-01-15   1.351351   Al-Qaeda
# 3 2012-01-22   1.192369   Al-Qaeda
# 4 2012-01-29   1.430843   Al-Qaeda

# %% [markdown]
# #### Analyse data

# %%
# Define a constant for the date of revelation
revelation_date = pd.Timestamp('2013-06-15')

# %% [markdown]
# Step 1

# %%
# Organise the data in a time series with the ratio of total views per week
terrorism_ts = terrorism_df.groupby(by='date').sum()
terrorism_ts = terrorism_ts.reset_index().rename(columns={'index': 'date'})

# Separate the data in two to perform an ITS analysis
terrorism_pre_june_ts = terrorism_ts[terrorism_ts['date'] < revelation_date]
terrorism_post_june_ts = terrorism_ts[terrorism_ts['date'] > revelation_date]

# %%
mean_pre_june = np.mean(terrorism_pre_june_ts['max_ratio'])
mean_post_june = np.mean(terrorism_post_june_ts['max_ratio'])
plt.bar([0, 1], [mean_pre_june, mean_post_june], color='gray', width=0.4)
plt.xticks([0, 1], ['Pre June, 2013', 'Post June, 2013'])
plt.ylabel("Average interest")
plt.xlim(-0.5, 1.5)
plt.ylim(0, 200)
plt.text(-0.1, mean_pre_june + 5, f"{mean_pre_june:.2f}")
plt.text(0.9, mean_post_june + 5, f"{mean_post_june:.2f}")
plt.show()

# %% [markdown]
# Step 2.1 - Show regression for terrorism

# %%
### TODO Modify description of the plot

# Visualisation of full time series
fig, ax = plt.subplots(figsize=(10, 6))

ax.set_title('Figure 2. Pre and Post June 2013 topic interest Trends \n\n', fontsize=14)
ax.set_xlabel('\nTime', fontsize=11)
ax.set_ylabel('Total interest (48 Google topics)\n', fontsize=11)
ax.set_ylim(0, 300)

ax.scatter(terrorism_ts.date, terrorism_ts.max_ratio, 
    label='Total Articles Views (By week)', color='black')

# Draw the regressions
slope_pre_june_ter, intercept_pre_june_ter, _, _, _ = stats.linregress(terrorism_pre_june_ts.index, 
                                                               terrorism_pre_june_ts.max_ratio)
slope_post_june_ter, intercept_post_june_ter, _, _, _ = stats.linregress(terrorism_post_june_ts.index,
                                                                 terrorism_post_june_ts.max_ratio)
x1 = terrorism_pre_june_ts.index
ax.plot(terrorism_pre_june_ts.date, intercept_pre_june_ter + slope_pre_june_ter*x1, 
    color='black', linewidth='3', label='Trend Pre-June 2013')
x2 = terrorism_post_june_ts.index
ax.plot(terrorism_post_june_ts.date, intercept_post_june_ter + slope_post_june_ter*x2, 
    color='gray', linewidth='3', label='Trend Post-June 2013')

# Emphasise when the revelations occured 
ax.axvline(x=revelation_date, ymin=0, ymax=280, color='black', linewidth='3')

x_text_offset = revelation_date - pd.Timedelta(50, 'd')
y_text_offset = 305
ax.text(x_text_offset, y_text_offset, 'Mid June 2013', fontsize=10)

ax.legend(loc='lower left')
plt.show()

# %% [markdown]
# Step 2.2 - Remove outliers

# %% [markdown]
# We observe that the graph above contains some outliers that may alter our analysis

# %%
fig, ax = plt.subplots(5, 1, figsize=(10, 18), sharey=True)

points_per_topic = len(terrorism_df)/len(set(terrorism_df['topic_name']))
topics_per_plot = 10
points_per_plot = points_per_topic * topics_per_plot

for i in range(5):
    sn.lineplot(data=terrorism_df[i*int(points_per_plot):(i+1)*int(points_per_plot)], 
                x='date', 
                y='max_ratio', 
                hue='topic_name', 
                ax=ax[i])
    ax[i].legend(bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# %% [markdown]
# #### Discussion:
#
# TODO

# %%
# Removal of all 
terrorism_clean_df = terrorism_df[~(terrorism_df['topic_name']== 'Iraq')]
terrorism_clean_df = terrorism_clean_df[~(terrorism_clean_df['topic_name']== 'Terrorism')]
terrorism_clean_df = terrorism_clean_df[~(terrorism_clean_df['topic_name']== 'Nigeria')]
terrorism_clean_df = terrorism_clean_df[~(terrorism_clean_df['topic_name']== 'Nuclear weapon')]
terrorism_clean_df = terrorism_clean_df[~(terrorism_clean_df['topic_name']== 'Hamas')]
terrorism_clean_df = terrorism_clean_df[~(terrorism_clean_df['topic_name']== 'Chemical weapon')]

# %%
# Organise the data in a time series with the ratio of total views per week
terrorism_clean_ts = terrorism_clean_df.groupby(by='date').sum()
terrorism_clean_ts = terrorism_clean_ts.reset_index().rename(columns={'index': 'date'})

# Separate the data in two to perform an ITS analysis
terrorism_pre_june_clean_ts = terrorism_clean_ts[terrorism_clean_ts['date'] < revelation_date]
terrorism_post_june_clean_ts = terrorism_clean_ts[terrorism_clean_ts['date'] > revelation_date]

# %%
#TODO: add comment here
mean_pre_june = np.mean(terrorism_pre_june_clean_ts['max_ratio'])
mean_post_june = np.mean(terrorism_post_june_clean_ts['max_ratio'])
plt.bar([0, 1], [mean_pre_june, mean_post_june], color='gray', width=0.4)
plt.xticks([0, 1], ['Pre June, 2013', 'Post June, 2013'])
plt.ylabel("Average interest")
plt.xlim(-0.5, 1.5)
plt.ylim(0, 200)
plt.text(-0.1, mean_pre_june + 5, f"{mean_pre_june:.2f}")
plt.text(0.9, mean_post_june + 5, f"{mean_post_june:.2f}")
plt.show()

# %%
### TODO Modify description of the plot

# Visualisation of full time series
fig, ax = plt.subplots(figsize=(10, 6))

ax.set_title('Pre and Post June 2013 Topic interest Trends (without outliers)\n\n', fontsize=14)
ax.set_xlabel('\nTime', fontsize=11)
ax.set_ylabel('Total views (48 Google Articles)\n', fontsize=11)
ax.set_ylim(0, 300)

ax.scatter(terrorism_clean_ts.date, terrorism_clean_ts.max_ratio, 
    label='Total Articles interest (By week)', color='black')

# Draw the regressions
slope_pre_june_clean, intercept_pre_june_clean, _, _, _ = stats.linregress(terrorism_pre_june_clean_ts.index, 
                                                               terrorism_pre_june_clean_ts.max_ratio)
slope_post_june_clean, intercept_post_june_clean, _, _, _ = stats.linregress(terrorism_post_june_clean_ts.index,
                                                                 terrorism_post_june_clean_ts.max_ratio)
x1 = terrorism_pre_june_clean_ts.index
ax.plot(terrorism_pre_june_clean_ts.date, intercept_pre_june_clean + slope_pre_june_clean*x1, 
    color='black', linewidth='3', label='Trend Pre-June 2013')
x2 = terrorism_post_june_clean_ts.index
ax.plot(terrorism_post_june_clean_ts.date, intercept_post_june_clean + slope_post_june_clean*x2, 
    color='gray', linewidth='3', label='Trend Post-June 2013')

# Emphasise when the revelations occured 
ax.axvline(x=revelation_date, ymin=0, ymax=280, color='black', linewidth='3')

x_text_offset = revelation_date - pd.Timedelta(50, 'd')
y_text_offset = 305
ax.text(x_text_offset, y_text_offset, 'Mid June 2013', fontsize=10)
ax.legend(loc='lower left')
plt.show()

# %% [markdown]
# #### Discussion:
#
# TODO

# %% [markdown]
# Step 3.1 - Compare with domestic and

# %%
# Organise the data in time series with the ratio of total views per week
terrorism30_ts = terrorism30_df.groupby(by='date').sum()
terrorism30_ts = terrorism30_ts.reset_index().rename(columns={'index': 'date'})

domestic_ts = domestic_df.groupby(by='date').sum()
domestic_ts = domestic_ts.reset_index().rename(columns={'index': 'date'})

infrastructure_ts = infrastructure_df.groupby(by='date').sum()
infrastructure_ts = infrastructure_ts.reset_index().rename(columns={'index': 'date'})

# Separate the data in two to perform an ITS analysis
terrorism30_pre_june_ts = terrorism30_ts[terrorism30_ts['date'] < revelation_date]
terrorism30_post_june_ts = terrorism30_ts[terrorism30_ts['date'] > revelation_date]

domestic_pre_june_ts = domestic_ts[domestic_ts['date'] < revelation_date]
domestic_post_june_ts = domestic_ts[domestic_ts['date'] > revelation_date]

infrastructure_pre_june_ts = infrastructure_ts[infrastructure_ts['date'] < revelation_date]
infrastructure_post_june_ts = infrastructure_ts[infrastructure_ts['date'] > revelation_date]

# %%
def make_regression_plot(df_pre, df_post, ax, name="Terrorism", color="black"):
    """ Draw the data points, regressions & CIs """
    sn.regplot(x=df_pre.index, y=df_pre.max_ratio, data=df_pre, color=color,
            label=f"{name} interest Trend Pre-June", scatter=True, n_boot=10000, ax=ax)

    sn.regplot(x=df_post.index, y=df_post.max_ratio, data=df_post, color=color,
            label=f"{name} interest Trend Post-June", scatter=True, n_boot=10000, ax=ax)

# %%
### Show the figure before outliers removal of both terrorism articles study group and the comparator group
## Visualisation of the full time series
fig, ax = plt.subplots(figsize=(10, 6))

# Draw terrorism data (pre/post june) plot
make_regression_plot(terrorism30_pre_june_ts, terrorism30_post_june_ts, ax=ax, name="Terrorism")
# Draw domestic data (pre/post june) plot
make_regression_plot(domestic_pre_june_ts, domestic_post_june_ts, ax=ax, name="Security", color="blue")

# Emphasise when the revelations occured 
revelation_date_integer = 75.5
ax.axvline(x=revelation_date_integer, ymin=0, ymax=160, color='black', linewidth='3')

x_text_offset = revelation_date_integer - 5
y_text_offset = 180
ax.text(x_text_offset, y_text_offset, 'Mid June 2013', fontsize=10)

ax.collections[3].set_label('Confidence interval (95%)')
ax.collections[7].set_label('Confidence interval (95%)')

ax.set_title('Topic interest Trends for terrorism Articles Study Group vs. Domestic Security Comparator Group\n\n', fontsize=14)
ax.set_xlabel('\nTime (Weeks)', fontsize=11)
ax.set_ylabel('Total interest (All topics)\n', fontsize=11)
ax.legend(loc='upper right')

plt.show()

# %%
### Show the figure before outliers removal of infrastructure comparator group
## Visualisation of the full time series
fig, ax = plt.subplots(figsize=(10, 6))

# Draw infrastructure data (pre/post june) plot
make_regression_plot(infrastructure_pre_june_ts, infrastructure_post_june_ts, ax=ax, name="Infrastructure", color="green")

# Emphasise when the revelations occured 
revelation_date_integer = 75.5
ax.axvline(x=revelation_date_integer, ymin=0, ymax=160, color='black', linewidth='3')

x_text_offset = revelation_date_integer - 5
y_text_offset = 635
ax.text(x_text_offset, y_text_offset, 'Mid June 2013', fontsize=10)

ax.collections[3].set_label('Confidence interval (95%)')

ax.set_title('Topic interest Trends for Infrastructure Security Comparator Group\n\n', fontsize=14)
ax.set_xlabel('\nTime (Weeks)', fontsize=11)
ax.set_ylabel('Total interest (All topics)\n', fontsize=11)
ax.legend(loc='upper right')

plt.show()

# %% [markdown]
# Step 3.2 - Look for outliers

# %%
def plot_all_timeseries(df):
    fig, ax = plt.subplots(3, 1, figsize=(10, 14), sharey=True)

    points_per_topic = len(df)/len(set(df['topic_name']))
    topics_per_plot = 10
    points_per_plot = points_per_topic * topics_per_plot

    for i in range(3):
        sn.lineplot(data=df[i*int(points_per_plot):(i+1)*int(points_per_plot)], 
                    x='date', 
                    y='max_ratio', 
                    hue='topic_name', 
                    ax=ax[i])
        ax[i].legend(bbox_to_anchor=(1.05, 1), loc='upper left')

    plt.show()

# %%
plot_all_timeseries(terrorism30_df)

# %%
plot_all_timeseries(domestic_df)

# %%
plot_all_timeseries(infrastructure_df)

# %%
terrorism30_clean_df = terrorism30_df[~(terrorism30_df['topic_name']== 'Terrorism')]
terrorism30_clean_df = terrorism30_clean_df[~(terrorism30_clean_df['topic_name']== 'Nuclear weapon')]
terrorism30_clean_df = terrorism30_clean_df[~(terrorism30_clean_df['topic_name']== 'Chemical weapon')]

domestic_clean_df = domestic_df[~(domestic_df['topic_name']== 'Federal Bureau of Investigation')]
domestic_clean_df = domestic_clean_df[~(domestic_clean_df['topic_name']== 'Federal Emergency Management Agency')]
domestic_clean_df = domestic_clean_df[~(domestic_clean_df['topic_name']== 'United States Secret Service')]

infrastructure_clean_df = infrastructure_df[~(infrastructure_df['topic_name']== 'Airplane')]
infrastructure_clean_df = infrastructure_clean_df[~(infrastructure_clean_df['topic_name']== 'Airport')]
infrastructure_clean_df = infrastructure_clean_df[~(infrastructure_clean_df['topic_name']== 'Power outage')]

# %%
# Organise the data in time series with the ratio of total views per week
terrorism30_clean_ts = terrorism30_clean_df.groupby(by='date').sum()
terrorism30_clean_ts = terrorism30_clean_ts.reset_index().rename(columns={'index': 'date'})

domestic_clean_ts = domestic_clean_df.groupby(by='date').sum()
domestic_clean_ts = domestic_clean_ts.reset_index().rename(columns={'index': 'date'})

infrastructure_clean_ts = infrastructure_clean_df.groupby(by='date').sum()
infrastructure_clean_ts = infrastructure_clean_ts.reset_index().rename(columns={'index': 'date'})


# Separate the data in two to perform an ITS analysis
terrorism30_pre_june_clean_ts = terrorism30_clean_ts[terrorism30_clean_ts['date'] < revelation_date]
terrorism30_post_june_clean_ts = terrorism30_clean_ts[terrorism30_clean_ts['date'] > revelation_date]

domestic_pre_june_clean_ts = domestic_ts[domestic_clean_ts['date'] < revelation_date]
domestic_post_june_clean_ts = domestic_ts[domestic_clean_ts['date'] > revelation_date]

infrastructure_pre_june_clean_ts = infrastructure_clean_ts[infrastructure_clean_ts['date'] < revelation_date]
infrastructure_post_june_clean_ts = infrastructure_clean_ts[infrastructure_clean_ts['date'] > revelation_date]

# %%
### Show the final figure with both terrorism articles study group and the comparator group
## Visualisation of the full time series
fig, ax = plt.subplots(figsize=(10, 6))

# Draw terrorism data (pre/post june) plot
make_regression_plot(terrorism30_pre_june_clean_ts, terrorism30_post_june_clean_ts, ax=ax, name="Terrorism")
# Draw domestic data (pre/post june) plot
make_regression_plot(domestic_pre_june_clean_ts, domestic_post_june_clean_ts, ax=ax, name="Security", color="blue")

# Emphasise when the revelations occured 
revelation_date_integer = 75.5
ax.axvline(x=revelation_date_integer, ymin=0, ymax=160, color='black', linewidth='3')

x_text_offset = revelation_date_integer - 5
y_text_offset = 180
ax.text(x_text_offset, y_text_offset, 'Mid June 2013', fontsize=10)

ax.collections[3].set_label('Confidence interval (95%)')
ax.collections[7].set_label('Confidence interval (95%)')

ax.set_title('Topic interest Trends for terrorism Articles Study Group vs. Domestic Security Comparator Group\n\n', fontsize=14)
ax.set_xlabel('\nTime (Weeks)', fontsize=11)
ax.set_ylabel('Total interest (All topics)\n', fontsize=11)
ax.legend(loc='upper right')

plt.show()

# %%
### Show the final figure with infrastructure comparator group
## Visualisation of the full time series
fig, ax = plt.subplots(figsize=(10, 6))

# Draw infrastructure data (pre/post june) plot
make_regression_plot(infrastructure_pre_june_clean_ts, infrastructure_post_june_clean_ts, ax=ax, name="Infrastructure", color="green")

# Emphasise when the revelations occured 
revelation_date_integer = 75.5
ax.axvline(x=revelation_date_integer, ymin=0, ymax=160, color='black', linewidth='3')

x_text_offset = revelation_date_integer - 5
y_text_offset = 248
ax.text(x_text_offset, y_text_offset, 'Mid June 2013', fontsize=10)

ax.collections[3].set_label('Confidence interval (95%)')

ax.set_title('Topic interest Trends for Infrastructure Security Comparator Group\n\n', fontsize=14)
ax.set_xlabel('\nTime (Weeks)', fontsize=11)
ax.set_ylabel('Total interest (All topics)\n', fontsize=11)
ax.legend(loc='upper right')

plt.show()

# %% [markdown]
# ### Discussion:
# #### Limitations of our approach:
#
# 1. Locality and different reference point:
# GTab still has some limitations. Indeed, we can only compare queries as long as they use the same anchorbank. If we want to query google trends for different countries we have to use different anchor banks. This means that we cannot quantitatively compare results for different countries. However, we can still offer qualitative insight based on our results. For instance positive trends will stay positive with any reference point.

# %%
import plotly.tools as pt
import pandas as pd
import chart_studio.tools as tls
import chart_studio.plotly as py
import plotly.graph_objects as go

username = "Arturjssln"
api_key = "H4XMtrMMVkVIcRDyhuc2"
tls.set_credentials_file(username=username, api_key=api_key)

fig = go.Figure()
fig.add_trace(go.Bar(x=[0, 1], y=[mean_pre_june, mean_post_june], name="Average interest", width=0.8))
fig.update_traces(marker_color='#1f78b4')

fig.update_layout(template='plotly_white')
fig.update_layout(title='Figure 2: Terrorism-related articles average interest', xaxis=dict(tickmode='array', tickvals=[0,1],ticktext=['Pre June, 2013', 'Post June, 2013']))
fig.update_yaxes(title_text='Average interest', range=[0,100])
fig.update_xaxes(range=[-1,2])


# Get html code for figure
url = py.plot(fig, filename = 'fig2', auto_open=True)
print(tls.get_embed(url))

EVENT_DATE = pd.to_datetime('2013-06-15')

fig = go.Figure()
terrorism_marged_ts = pd.concat([terrorism_pre_june_ts, terrorism_post_june_ts], axis=0)
fig.add_trace(go.Scatter(x=terrorism_marged_ts.date, y=terrorism_marged_ts.max_ratio, name = 'Total interest (Terrorism)', mode='markers', line = dict(color = '#1f78b4', width = 4)))
fig.add_trace(go.Scatter(x=terrorism_pre_june_ts.date, y=intercept_pre_june_ter + slope_pre_june_ter*terrorism_pre_june_ts.index, name = 'Terrorism-related Trend Pre-June 2013', mode='lines', line = dict(color = '#1f78b4', width = 4)))
fig.add_trace(go.Scatter(x=terrorism_post_june_ts.date, y=intercept_post_june_ter + slope_post_june_ter*terrorism_post_june_ts, name = 'Terrorism-related Trend Post-June 2013', mode='lines', line = dict(color = '#a6cee3', width = 4)))

fig.update_layout(template='plotly_white')
fig.update_layout(title='Figure 3: terrorism-related articles interest trends')
fig.update_xaxes(title_text='Time', tickangle=-45)
fig.update_yaxes(title_text='Total interest by week', range=[0, 150])
fig.add_vline(x=EVENT_DATE, line = dict(color = 'black', width = 4))
fig.add_annotation(x=EVENT_DATE, y=130,
            text="Mid-June 2013",
            showarrow=True,
            arrowhead=4,
            arrowwidth=2,
            ax=100)
fig.update_layout(legend = dict(x = 0.0, y = 0.0))
url = py.plot(fig, filename = 'fig3', auto_open=True)

print(url)
print(tls.get_embed(url))


fig = go.Figure()
terrorism_marged_ts = pd.concat([terrorism_pre_june_ts, terrorism_post_june_ts], axis=0)
fig.add_trace(go.Scatter(x=terrorism_marged_ts.date, y=terrorism_marged_ts.max_ratio, name = 'Total interest (Terrorism)', mode='markers', line = dict(color = '#1f78b4', width = 4)))
fig.add_trace(go.Scatter(x=terrorism_pre_june_ts.date, y=intercept_pre_june_ter + slope_pre_june_ter*terrorism_pre_june_ts.index, name = 'Terrorism-related Trend Pre-June 2013', mode='lines', line = dict(color = '#1f78b4', width = 4)))
fig.add_trace(go.Scatter(x=terrorism_post_june_ts.date, y=intercept_post_june_ter + slope_post_june_ter*terrorism_post_june_ts.index, name = 'Terrorism-related Trend Post-June 2013', mode='lines', line = dict(color = '#a6cee3', width = 4)))

slope_pre_june_dom, intercept_pre_june_dom, _, _, _ = stats.linregress(domestic_pre_june_ts.index, 
                                                               domestic_pre_june_ts.max_ratio)
slope_post_june_dom, intercept_post_june_dom, _, _, _ = stats.linregress(domestic_post_june_ts.index,
                                                                 domestic_post_june_ts.max_ratio)

domestic_marged_ts = pd.concat([domestic_pre_june_ts, domestic_post_june_ts], axis=0)
fig.add_trace(go.Scatter(x=domestic_marged_ts.date, y=domestic_marged_ts.max_ratio, name = 'Total interest (Security)', mode='markers', line = dict(color = '#33a02c', width = 4)))
fig.add_trace(go.Scatter(x=domestic_pre_june_ts.date, y=intercept_pre_june_dom + slope_pre_june_dom*domestic_pre_june_ts.index, name = 'Security-related Trend Pre-June 2013', mode='lines', line = dict(color = '#33a02c', width = 4)))

fig.add_trace(go.Scatter(x=domestic_post_june_ts.date, y=intercept_post_june_dom + slope_post_june_dom*domestic_post_june_ts.index, name = 'Security-related Trend Post-June 2013', mode='lines', line = dict(color = '#78c879', width = 4)))

fig.update_layout(template='plotly_white')
fig.update_layout(title='Figure 4: terrorism- and security-related articles interest trends')
fig.update_xaxes(title_text='Time', tickangle=-45)
fig.update_yaxes(title_text='Total interest by week', range=[0, 150])
fig.add_vline(x=EVENT_DATE, line = dict(color = 'black', width = 4))
fig.add_annotation(x=EVENT_DATE, y=130,
            text="Mid-June 2013",
            showarrow=True,
            arrowhead=4,
            arrowwidth=2,
            ax=100)
fig.update_layout(legend = dict(x = 0.0, y = 0.0))

url = py.plot(fig, filename = 'fig4', auto_open=True)

print(url)
print(tls.get_embed(url))

fig = go.Figure()
terrorism_marged_ts = pd.concat([terrorism_pre_june_clean_ts, terrorism_post_june_clean_ts], axis=0)
fig.add_trace(go.Scatter(x=terrorism_marged_ts.date, y=terrorism_marged_ts.max_ratio, name = 'Total interest (Terrorism)', mode='markers', line = dict(color = '#1f78b4', width = 4)))
fig.add_trace(go.Scatter(x=terrorism_pre_june_clean_ts.date, y=intercept_pre_june_clean + slope_pre_june_clean*terrorism_pre_june_clean_ts.index, name = 'Terrorism-related Trend Pre-June 2013', mode='lines', line = dict(color = '#1f78b4', width = 4)))
fig.add_trace(go.Scatter(x=terrorism_post_june_clean_ts.date, y=intercept_post_june_clean + slope_post_june_clean*terrorism_post_june_clean_ts.index, name = 'Terrorism-related Trend Post-June 2013', mode='lines', line = dict(color = '#a6cee3', width = 4)))

slope_pre_june_dom, intercept_pre_june_dom, _, _, _ = stats.linregress(domestic_pre_june_clean_ts.index, domestic_pre_june_clean_ts.max_ratio)
slope_post_june_dom, intercept_post_june_dom, _, _, _ = stats.linregress(domestic_post_june_clean_ts.index, domestic_post_june_clean_ts.max_ratio)

domestic_marged_ts = pd.concat([domestic_pre_june_ts, domestic_post_june_ts], axis=0)
fig.add_trace(go.Scatter(x=domestic_marged_ts.date, y=domestic_marged_ts.max_ratio, name = 'Total interest (Security)', mode='markers', line = dict(color = '#33a02c', width = 4)))
fig.add_trace(go.Scatter(x=domestic_pre_june_clean_ts.date, y=intercept_pre_june_dom + slope_pre_june_dom*domestic_pre_june_clean_ts.index, name = 'Security-related Trend Pre-June 2013', mode='lines', line = dict(color = '#33a02c', width = 4)))
fig.add_trace(go.Scatter(x=domestic_post_june_clean_ts.date, y=intercept_post_june_dom + slope_post_june_dom*domestic_post_june_clean_ts.index, name = 'Security-related Trend Post-June 2013', mode='lines', line = dict(color = '#78c879', width = 4)))

fig.update_layout(template='plotly_white')
fig.update_layout(title='Figure 5: terrorism- and security-related articles interest trends')
fig.update_xaxes(title_text='Time', tickangle=-45)
fig.update_yaxes(title_text='Total interest by monweekth', range=[0, 150])
fig.add_vline(x=EVENT_DATE, line = dict(color = 'black', width = 4))
fig.add_annotation(x=EVENT_DATE, y=130,
            text="Mid-June 2013",
            showarrow=True,
            arrowhead=4,
            arrowwidth=2,
            ax=100)
fig.update_layout(legend = dict(x = 0.0, y = 0.0))
            
url = py.plot(fig, filename = 'fig5', auto_open=True)
print(url)
print(tls.get_embed(url))
# Out:
# ---------------------------------------------------------------------------
# PlotlyRequestError                        Traceback (most recent call last)
# ~/anaconda3/envs/ada/lib/python3.7/site-packages/chart_studio/plotly/plotly.py in _create_or_update(data, filetype)
#    1462         try:
# -> 1463             lookup_res = v2.files.lookup(filename)
#    1464             if isinstance(lookup_res.content, bytes):
#
# ~/anaconda3/envs/ada/lib/python3.7/site-packages/chart_studio/api/v2/files.py in lookup(path, parent, user, exists)
#      84     params = make_params(path=path, parent=parent, user=user, exists=exists)
# ---> 85     return request("get", url, params=params)
#
# ~/anaconda3/envs/ada/lib/python3.7/site-packages/retrying.py in wrapped_f(*args, **kw)
#      48             def wrapped_f(*args, **kw):
# ---> 49                 return Retrying(*dargs, **dkw).call(f, *args, **kw)
#      50
#
# ...

# %%
print(terrorism_pre_june_ts)
